# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("Maternal Health Risk Data Set.csv")
dataset.head()
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.0      98.0         86  high risk
# 1   35         140           90  13.0      98.0         70  high risk
# 2   29          90           70   8.0     100.0         80  high risk
# 3   30         140           85   7.0      98.0         70  high risk
# 4   35         120           60   6.1      98.0         76   low risk

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          1014 non-null   int64
#  1   SystolicBP   1014 non-null   int64
#  2   DiastolicBP  1014 non-null   int64
#  3   BS           1014 non-null   float64
#  4   BodyTemp     1014 non-null   float64
#  5   HeartRate    1014 non-null   int64
#  6   RiskLevel    1014 non-null   object
# dtypes: float64(2), int64(4), object(1)
# memory usage: 55.6+ KB

# %%
dataset.isnull().sum()
# Out:
# Age            0
# SystolicBP     0
# DiastolicBP    0
# BS             0
# BodyTemp       0
# HeartRate      0
# RiskLevel      0
# dtype: int64

# %%
dataset.duplicated()
print(f"The total number of duplicated data is {dataset.duplicated().sum()}")
# Out:
# The total number of duplicated data is 562

# %%
dataset.loc[dataset.duplicated(), :]
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 67     19         120           80   7.0      98.0         70   mid risk
# 72     19         120           80   7.0      98.0         70   mid risk
# 97     19         120           80   7.0      98.0         70   mid risk
# 106    50         140           90  15.0      98.0         90  high risk
# 107    25         140          100   6.8      98.0         80  high risk
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk
#
# [562 rows x 7 columns]

# %%
dataset.describe().T
# Out:
#               count        mean        std   min    25%    50%    75%    max
# Age          1014.0   29.871795  13.474386  10.0   19.0   26.0   39.0   70.0
# SystolicBP   1014.0  113.198225  18.403913  70.0  100.0  120.0  120.0  160.0
# DiastolicBP  1014.0   76.460552  13.885796  49.0   65.0   80.0   90.0  100.0
# BS           1014.0    8.725986   3.293532   6.0    6.9    7.5    8.0   19.0
# BodyTemp     1014.0   98.665089   1.371384  98.0   98.0   98.0   98.0  103.0
# HeartRate    1014.0   74.301775   8.088702   7.0   70.0   76.0   80.0   90.0

# %%
# Unique Values of RiskLevel (Target Variable)
dataset["RiskLevel"].unique()
# Out:
# array(['high risk', 'low risk', 'mid risk'], dtype=object)

# %%
# Frequency Counts of each RiskLevel Value
dataset["RiskLevel"].value_counts()
# Out:
# low risk     406
# mid risk     336
# high risk    272
# Name: RiskLevel, dtype: int64

# %%
# Use hsitogram plot "RiskLevel" column of MHR dataset (object)
plt.hist(dataset["RiskLevel"])
# Label axes
plt.xlabel("RiskLevel")
plt.ylabel("Count")
# Add title
plt.title("Distribution of RiskLevel");

# %%
plt.scatter(dataset["Age"], dataset['RiskLevel'])
plt.title("Scatter Plot of Age Against the Risk level")
plt.xlabel('Age')
plt.ylabel('RiskLevel')
plt.show()

# %%
def num_plot(data, col):
    fig, ax = plt.subplots(1, 2, figsize=(10, 4))
    sns.histplot(data=data, x=col, kde=True, ax=ax[0])
    sns.boxplot(data=data, x=col, ax=ax[1])
    ax[0].set_title(f"{col} Distribution Histogram")
    ax[1].set_title(f"{col} Distribution Boxplot")
    plt.show()

# %%
num_plot(dataset,"Age")

# %%
num_plot(dataset, "SystolicBP")

# %%
num_plot(dataset, "DiastolicBP")

# %%
num_plot(dataset, "BS")

# %%
num_plot(dataset, "BodyTemp")

# %%
num_plot(dataset, "HeartRate")
